# %% [markdown]
# Write a program for collecting a string from the user and counting the number of vowels.
#
# Print the total count of vowels
# Print each vowel and its count
# Calculate the percentage of vowels in the given string
# Make use of functions and format your output accordingly

# %%
def vowelcounter(intstring) :
    vowel = "aeiouAEIOU"
    vowelscount = {}
    count = 0

    for i in intstring :
        if i in vowel :
            if i in vowelscount :
                vowelscount[i] += 1
            else :
                vowelscount[i] = 1
                count +=1
    return vowelscount,countit 

def stringcount():
    a = input("enter the string")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\GIT\MScDSA-MDS171---23122013-Chirag\LAB WORK\Lab - 06.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/d%3A/GIT/MScDSA-MDS171---23122013-Chirag/LAB%20WORK/Lab%20-%2006.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a>             print(count)
#      <a href='vscode-notebook-cell:/d%3A/GIT/MScDSA-MDS171---23122013-Chirag/LAB%20WORK/Lab%20-%2006.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     return True
# ---> <a href='vscode-notebook-cell:/d%3A/GIT/MScDSA-MDS171---23122013-Chirag/LAB%20WORK/Lab%20-%2006.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> vowelcounter(vowel,a,count,sum)
#
# NameError: name 'vowel' is not defined

# %%
# Out:
# 0
