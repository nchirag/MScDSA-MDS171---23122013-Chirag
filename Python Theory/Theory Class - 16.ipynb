# %%
import pandas as pd
df = pd.read_csv("D:\GIT\MScDSA-MDS171---23122013-Chirag\Python Theory\cars.csv")
df
# Out:
#       First Name   Last Name         Country Car Brand     Car Model  \
# 0          Yetty     Arghent       Indonesia      Ford    Club Wagon
# 1        Crystal    Bosworth           China  Cadillac  Escalade ESV
# 2          Monro    Houdhury       Indonesia     Mazda    Miata MX-5
# 3          Bowie       Clair           China      Audi            A4
# 4         Myrvyn  McAllister  Czech Republic    Nissan        Maxima
# ...          ...         ...             ...       ...           ...
# 29995     Valida      Smoote     Afghanistan    Nissan        Altima
# 29996     Anthea      Deport       Indonesia       Kia           Rio
# 29997  Albertine     Danelut           Japan    Toyota   Tacoma Xtra
# 29998     Alayne       Golda      Kyrgyzstan      Audi        riolet
# 29999    Ibrahim   Dobrovsky       Indonesia     Lotus        Esprit
#
#        Car Color  Year of Manufacture Credit Card Type
# 0           Teal                 1993       mastercard
# ...

# %%
df.rename(columns = {"Car Brand":"Car Company"},inplace = True)
display(df)
# Out:
#       First Name   Last Name         Country Car Company     Car Model  \
# 0          Yetty     Arghent       Indonesia        Ford    Club Wagon
# 1        Crystal    Bosworth           China    Cadillac  Escalade ESV
# 2          Monro    Houdhury       Indonesia       Mazda    Miata MX-5
# 3          Bowie       Clair           China        Audi            A4
# 4         Myrvyn  McAllister  Czech Republic      Nissan        Maxima
# ...          ...         ...             ...         ...           ...
# 29995     Valida      Smoote     Afghanistan      Nissan        Altima
# 29996     Anthea      Deport       Indonesia         Kia           Rio
# 29997  Albertine     Danelut           Japan      Toyota   Tacoma Xtra
# 29998     Alayne       Golda      Kyrgyzstan        Audi        riolet
# 29999    Ibrahim   Dobrovsky       Indonesia       Lotus        Esprit
#
#        Car Color  Year of Manufacture Credit Card Type
# 0           Teal                 1993       mastercard
# ...

# %%
df['Car Company']
display(df)
# Out:
#       First Name   Last Name         Country Car Company     Car Model  \
# 0          Yetty     Arghent       Indonesia        Ford    Club Wagon
# 1        Crystal    Bosworth           China    Cadillac  Escalade ESV
# 2          Monro    Houdhury       Indonesia       Mazda    Miata MX-5
# 3          Bowie       Clair           China        Audi            A4
# 4         Myrvyn  McAllister  Czech Republic      Nissan        Maxima
# ...          ...         ...             ...         ...           ...
# 29995     Valida      Smoote     Afghanistan      Nissan        Altima
# 29996     Anthea      Deport       Indonesia         Kia           Rio
# 29997  Albertine     Danelut           Japan      Toyota   Tacoma Xtra
# 29998     Alayne       Golda      Kyrgyzstan        Audi        riolet
# 29999    Ibrahim   Dobrovsky       Indonesia       Lotus        Esprit
#
#        Car Color  Year of Manufacture Credit Card Type
# 0           Teal                 1993       mastercard
# ...
